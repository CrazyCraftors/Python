# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

imagen = cv2.imread('imagen.jpeg', cv2.IMREAD_COLOR)
imagenRGB = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
imgc=imagenRGB.copy()

# %%
imagen.shape
# Out:
# (720, 1080, 3)

# %%
objetivo=imagenRGB[225:505,400:710]
objetivo.shape
# Out:
# (280, 310, 3)

# %%
black=np.where((imagenRGB[:,:,0])&(imagenRGB[:,:,1])&(imagenRGB[:,:,2]))
black
# Out:
# (array([  0,   0,   0, ..., 719, 719, 719], dtype=int64),
#  array([  19,   23,   24, ..., 1077, 1078, 1079], dtype=int64))

# %%
imgc[425:705,700:1010]=objetivo

# %%
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
plt.title('Imagen Original')
plt.imshow(imagenRGB)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('recorte')
plt.imshow(objetivo)
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('añadido')
plt.imshow(imgc)
plt.axis('off')


plt.tight_layout()
plt.show()
